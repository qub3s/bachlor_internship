# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# %% [markdown]
# # Representative Images for Davis

# %%
data_dir = "../data/DAVIS_trainval/"

image_path = data_dir + "JPEGImages/480p/"
annotation_path = data_dir + "Annotations/480p/"

image_dirs = os.listdir(image_path)
annotation_dirs = os.listdir(annotation_path)

def get_num_images():
    return len(image_dirs)

def get_image( i ):
    list_of_images = []
    list_of_annotations = []

    for im, an in zip(sorted(os.listdir(image_path+image_dirs[i])), sorted(os.listdir(annotation_path+annotation_dirs[i]))):
        temp = cv2.cvtColor(cv2.imread(image_path+image_dirs[i] +  "/" + im), cv2.COLOR_RGB2BGR)
        list_of_images.append(temp)
        
        temp = cv2.cvtColor(cv2.imread(annotation_path+annotation_dirs[i] +  "/" + an), cv2.COLOR_RGB2BGR)
        list_of_annotations.append(temp)
    
    return image_dirs[i], np.array(list_of_images), np.array(list_of_annotations)

print(get_image(0))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [3], line 6
#       3 image_path = data_dir + "JPEGImages/480p/"
#       4 annotation_path = data_dir + "Annotations/480p/"
# ----> 6 image_dirs = os.listdir(image_path)
#       7 annotation_dirs = os.listdir(annotation_path)
#       9 def get_num_images():
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/DAVIS_trainval/JPEGImages/480p/'

# %% [markdown]
# # Values for the First Run

# %%
test_values = [ 0.5202447670438655, 0.5804442968177792, 0.6080902695944339, 0.6059774165852542, 0.5918292316859881, 0.5947840632813657, 0.6016086887222036, 0.6035488394663571 ]
rounds = [0, 14, 28, 42, 56, 70, 84, 98]
run_values = [ 0.4203688059415095, 0.5220000505903818, 0.598099940196574, 0.5418735148847376, 0.44610559635247193, 0.5131034640395798, 0.5153591584822201, 0.6364011271667167, 0.5171424478734171, 0.5334480499965226, 0.4527125227876706, 0.4755822128857967, 0.6160949479980028, 0.5904554083574044, 0.4723597581053188, 0.4639404844544225, 0.5373124956416887, 0.4689378364385882, 0.5795251266326057, 0.4903421225156201, 0.5145180062854806, 0.4053891047445834, 0.4988053102750745, 0.5656089715630832, 0.5069950996703326, 0.4359037497558391, 0.5363412591990445, 0.5898934434493417, 0.485318590107711, 0.38085861557225004, 0.5238780802694044, 0.5259984373471209, 0.4698353420208921, 0.4501890145382339, 0.576639732725097, 0.42605447259979257, 0.4645359364091285, 0.5044726953231192, 0.5241593872483931, 0.5670857570171162, 0.48487774768665554, 0.5967696930706684, 0.4843127018498602, 0.5059059705841146, 0.5662880462047267, 0.48376697700263344, 0.5032683466983233, 0.38877777386752327, 0.43905247249789797, 0.6241695025383313, 0.5015847930766537, 0.5300289820769102, 0.4499673476758215, 0.5455192640344328, 0.5480492997126202, 0.49833962836204754, 0.5871419999060483, 0.5775246733537253, 0.5149942704168754, 0.5420521578569637, 0.48341500696767187, 0.5119609031353629, 0.5635495429824338, 0.5477778156589086, 0.5491498433287699, 0.5849530594020054, 0.48152540086491913, 0.5972026740816008, 0.49512124728565154, 0.5545723519004002, 0.530764255098683, 0.6556366751247067, 0.5350806867059055, 0.4961278203842655, 0.5906385319305658, 0.5665157071859849, 0.5189913417632178, 0.5842193088198512, 0.5181299424334032, 0
.6215147925995884, 0.5638849419725734, 0.5967746331030241, 0.5758270987108466, 0.5613475207303065, 0.5216762714236998, 0.5873057476225794, 0.5900971468975428, 0.5217567358152626, 0.5449197834910725, 0.5575684449112802, 0.5466820886041996, 0.5587062370677398, 0.57702448905365, 0.5738336360735766, 0.5857248303498122, 0.5433541754567096, 0.5900957355008791, 0.5149695811340855, 0.5292176838184274, 0.5494835289661015, 0.582038041994889, 0.5345445147571094, 0.5598603459020483, 0.6025943247700959, 0.5808808979809134, 0.5996417378559642, 0.6098875701927488, 0.5683269149908777, 0.5923929373579091, 0.5749717207443535, 0.6049452183081446, 0.5618612977109793, 0.5899137750069097, 0.5676000842314824, 0.5770431899871015, 0.5683586498189948, 0.5082973501256394, 0.545257053697998, 0.5346163460222435, 0.5470695771595679, 0.5356659393040506, 0.559227304340382, 0.5926759225971788, 0.6034567819560511, 0.5780576749509236, 0.5977742526359948, 0.59902143048381, 0.5854166454609637, 0.5586912258778062, 0.5929429209813881, 0.5774842135079611, 0.5571608791490723, 0.5584809834571312, 0.5436678365349137, 0.5648234642124489, 0.5880595167934732, 0.5754681234225061, 0.5676190240788486, 0.5457314586231412, 0.5527691720254382, 0.5825188283000812, 0.5643814203764697, 0.5998209737559689, 0.5813236045197365, 0.5646659444968284, 0.6034532320087695, 0.5430409602267012, 0.5766480432149385, 0.6134792716182086, 0.509054548989683, 0.6023647489856705, 0.5572670244322145, 0.5846201699390554, 0.534747525207297, 0.605794681896462, 0.6268828674483395, 0.5289865153309777, 0.549696632856873, 0.5620073652843425, 0.5827084753523251, 0.5664542431987113, 0.6045108784906397, 0.5808445160532063, 0.5799016747097681, 0.6215441323732053, 0.6346154796949451, 0.5740090113651696, 0.5708396249043651, 0.5683556223465689, 0.5522825828381993, 0.5964281775779058, 0.5738447882590146, 0.6003240521921381, 0.5561319841019521, 0.5935275779836645, 0.5536508282209142, 0.6127501459075151, 0.6158560952717607, 0.5509598345978665, 0.5764102565008158, 0.5481354349743744, 0.6078422923270577, 0.572440529982571, 0.5457154409604653]

print(len(test_values))
print(len(run_values))
# Out:
# 8
# 337

# %%
smoothed_data_10 = pd.Series(run_values).rolling(window=10, center=True).mean().dropna()
smoothed_data_30 = pd.Series(run_values).rolling(window=30, center=True).mean().dropna()

sns.lineplot(smoothed_data_30)
sns.lineplot(smoothed_data_10)
plt.xlabel("Round")
plt.ylabel("IoU Error")
# Out:
# Text(0, 0.5, 'IoU Error')

# %%
plt.plot(rounds, test_values)
plt.xlabel("Round")
plt.ylabel("IoU Error")
# Out:
# Text(0, 0.5, 'IoU Error')

# %% [markdown]
# # Segment Anything - 31 with optimized number of Masks

# %%
sam_values = [ 0.491110272438513, 0.4900607242571152, 0.49104766156162355, 0.49154606533304185, 0.488299502364954, 0.4859553270096306, 0.4844308133710155, 0.47901309350692195, 0.4752571836529523, 0.47007840025697717, 0.4634824596198759 ]
sam_categories = [ 0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

fig, ax = plt.subplots()

ax = sns.barplot(sam_values)
ax.set_ylim([0.45, 0.5])
ax.set_xticklabels(sam_categories)
# Out:
# /tmp/ipykernel_3722779/3970578978.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(sam_categories)
# [Text(0, 0, '0'),
#  Text(1, 0, '0.05'),
#  Text(2, 0, '0.1'),
#  Text(3, 0, '0.15'),
#  Text(4, 0, '0.2'),
#  Text(5, 0, '0.25'),
#  Text(6, 0, '0.3'),
#  Text(7, 0, '0.35'),
#  Text(8, 0, '0.4'),
#  Text(9, 0, '0.45'),
#  Text(10, 0, '0.5')]

# %% [markdown]
# # Segment Anything with increased Masks

# %%
sam_values = [ 0.464714710946816, 0.46306578378039026, 0.46163472174939435, 0.46329248943071266, 0.4656078124585057, 0.4577320799199232, 0.4550427501267157, 0.45093833748470175, 0.4464554280941648, 0.4429041878496266, 0.4429107476048847 ]
sam_categories = [ 0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

fig, ax = plt.subplots()

ax = sns.barplot(sam_values)
ax.set_ylim([0.43, 0.48])
ax.set_xticklabels(sam_categories)
# Out:
# /tmp/ipykernel_3722779/1517739002.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(sam_categories)
# [Text(0, 0, '0'),
#  Text(1, 0, '0.05'),
#  Text(2, 0, '0.1'),
#  Text(3, 0, '0.15'),
#  Text(4, 0, '0.2'),
#  Text(5, 0, '0.25'),
#  Text(6, 0, '0.3'),
#  Text(7, 0, '0.35'),
#  Text(8, 0, '0.4'),
#  Text(9, 0, '0.45'),
#  Text(10, 0, '0.5')]

# %% [markdown]
# # Values for the Second Run

# %%
test_values_2 = [0.6035488394663571, 0.6106185240961393, 0.6137904186725744, 0.6176479016551238, 0.6189244660421732, 0.615076697497298, 0.617614870433889]
rounds = [0, 14, 28, 42, 56, 70, 84]

test_values = test_values_2

run_values_2 = [ 0.568449854731171, 0.5777293651781893, 0.5751171378008263, 0.5756008692993285, 0.5559284627625793, 0.5898519021912679, 0.5802155389231153, 0.563082232291371, 0.596408827529824, 0.6089373277324337, 0.5180370450308998, 0.5384360904524907, 0.5345600033076896, 0.5765858011761088, 0.5319433107777025, 0.5222174299317166, 0.6363746325351456, 0.5653748962245173, 0.591232535845579, 0.5875457989629379, 0.6537906829374192, 0.5650749382206933, 0.5573111755519231, 0.5857607728503479, 0.5164554324274532, 0.5781914763806291, 0.608843858912403, 0.5718717569887843, 0.6173542450661992, 0.5134535119724967, 0.5876623866308351, 0.6048581937234582, 0.6729383002414636, 0.5390199612390543, 0.5545777251200436, 0.49128052417045226, 0.6169372533337699, 0.6458148372350572, 0.6112825758511807, 0.6307756469989583, 0.5139294150640709, 0.5795756618625282, 0.6200982113085837, 0.5698532212191953, 0.59959897720564, 0.5989395233990044, 0.5738070280105012, 0.5714608345286277, 0.5543760240014264, 0.6141099348798787, 0.5371496856898835, 0.5390705056661437, 0.5539967951841065, 0.6034473673803805, 0.5454749981598296, 0.6011352272222864, 0.5770767959712286, 0.568845199073001, 0.5940935368900224, 0.5775401951495666, 0.5989838545800481, 0.565866138689376, 0.5810864647475943, 0.631917615661818, 0.6048871118971897, 0.5909197889596149, 0.5893702971466173, 0.5711395035104654, 0.5758961284591892, 0.6266011082099369, 0.5915987994153914, 0.5335968231204455, 0.5578208827891367, 0.5832165925451673, 0.6066600678249447, 0.5750352745478813, 0.5478851536029956, 0.5882680796972136, 0.5775602246634552, 0.6259952617876325, 0.6087778959335487, 0.5692314608169317, 0.595485277045097, 0.5510795998250043, 0.5722499903281946, 0.5789968969992318, 0.5902116903505097, 0.5893119864866043, 0.6262733867664738, 0.595302684064086, 0.5749627766258671, 0.5799547778877474, 0.5931298174659599, 0.5944106056987484, 0.5802785076307332, 0.5634774051093867, 0.5840038901466821, 0.5774996827813382, 0.5884939107120721, 0.5971709922895573, 0.5851893946838924, 0.5696257081711412, 0.5859583045213299, 0.5852214375956237, 0.611320265794699, 0.6203161224644749, 0.5392088786771044, 0.5700319461956939, 0.5895654312802497, 0.5761014206137489, 0.5977723963988671, 0.5582040182902036, 0.6531587054348396, 0.5559815496088126, 0.48498065767775733, 0.5440510834750062, 0.6244985192827979, 0.5754427935993925, 0.5437474390296883, 0.5565667100038689, 0.523604870715863, 0.5478866391522174, 0.5984707950195006, 0.5615553362200008, 0.5902787880962493, 0.6217553200277893, 0.5938367413539037, 0.6153577249389035, 0.5672246093363511, 0.5841857176123041, 0.5524252975789198, 0.6266282668130794, 0.6335001484470054, 0.5745760882883655, 0.548891587842385, 0.5891760741390688, 0.5823874790218221, 0.6351892941291957, 0.5525666597204077, 0.5894187465652471, 0.6103130720234625, 0.5846613568149323 ]

run_values = run_values_2

print(len(test_values))
print(len(run_values))
# Out:
# 7
# 142

# %%
plt.plot(rounds, test_values)
plt.xlabel("Round")
plt.ylabel("IoU Error")
# Out:
# Text(0, 0.5, 'IoU Error')

# %%
# first and second test set values
#plt.figure(dpi=500)
plt.style.use('ggplot')
test_values_1 = [ 0.5202447670438655, 0.5804442968177792, 0.6080902695944339, 0.6059774165852542, 0.5918292316859881, 0.5947840632813657, 0.6016086887222036, 0.6035488394663571 ]

test_values = test_values_1 + test_values_2
rounds = range(0,15*2,2)

plt.plot(rounds, test_values)
plt.axvline(x=7.5*2, color="gray")
plt.plot(24, 0.6189244660421732, "ro", color="black")
plt.annotate('Selected model', xy=(24, 0.6189244660421732), xytext=(20.5,0.61))
plt.xlabel("Cycle")
plt.ylabel("IoU")
# Out:
# /tmp/ipykernel_3722779/3700324113.py:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(24, 0.6189244660421732, "ro", color="black")
# Text(0, 0.5, 'IoU')

# %%
# find the max difference between 2 points that follow each other

save = run_values_2[0]
max = 0
for x in run_values_2:
    diff = abs(save - x)
    if diff > max:
        max = diff

print(max)
# Out:
# 0.10448844551029257

# %% [markdown]
# ### First Train Run
#
# - 98 Rounds
# - Starting Masks: 5
# - Mask increase: 5
# - Decrase: 0.1
# - starting change: 0.1
#
# Last Values:
# ```
# ------------------------------------------------
# iou_error:            1.043553869070838
# lam_dis:              0.7323058003167556
# lam_col:              1.2796162745273871
# lam_cen:              1.1093688792966
# number_of_masks:      90.16043472256682
# bb_max_size:          3609.8354246590393
# threshhold_depth:     0.02112363122475415
# ------------------------------------------------
# ```
#
# Best Values:
# ```
# ------------------------------------------------
# iou_error:            0.963171
# lam_dis:              0.8437732212409792
# lam_col:              0.986628636721
# lam_cen:              1.146811182093569
# number_of_masks:      92.95185629423021
# bb_max_size:          3365.5929627322757
# threshhold_depth:     0.02758548378014531
# ------------------------------------------------
# ```
#
# ### Second Train Run
# - 92 Rounds
# - Starting Masks: 30
# - Mask increase: 5
# - Decrease: 0.05
# - starting change: 0.1
#
# ## Sam Testing for different Threshholds
# ```
# SAM:
# 0.0 : 0.491110272438513
# 0.05 : 0.4900607242571152
# 0.1 : 0.49104766156162355
# 0.15 : 0.49154606533304185
# 0.2 : 0.488299502364954
# 0.25 : 0.4859553270096306
# 0.3 : 0.4844308133710155
# 0.35 : 0.47901309350692195
# 0.4 : 0.4752571836529523
# 0.45 : 0.47007840025697717
# 0.5 : 0.4634824596198759
# ```
#
# ## Sam Testing for different Threshholds with more masks
# ```
# 0.0 : 0.464714710946816
# 0.05 : 0.46306578378039026
# 0.1 : 0.46163472174939435
# 0.15 : 0.46329248943071266
# 0.2 : 0.4656078124585057
# 0.25 : 0.4577320799199232
# 0.3 : 0.4550427501267157
# 0.35 : 0.45093833748470175
# 0.4 : 0.4464554280941648
# 0.45 : 0.4429041878496266
# 0.5 : 0.4429107476048847
# ```

# %% [markdown]
# test folder is best values
# image folder is last values

# %% [markdown]
# - On the tested system - dual core AMD EPYC 7302 (16-Cores) and NVIDIA RTX A5000 - my approach runs in roughly 80% the time
# - Inital 250 - Masks run at 0.5735882460697923 - IoU error with increase at the end so likely no overfit (performs better / as good as on the test set)

# %%
# first and second test set values
plt.figure(figsize=(25,5), dpi=1000)
plt.style.use('ggplot')
plt.subplot(1, 1, 1)

run_values_1 = [ 0.4203688059415095, 0.5220000505903818, 0.598099940196574, 0.5418735148847376, 0.44610559635247193, 0.5131034640395798, 0.5153591584822201, 0.6364011271667167, 0.5171424478734171, 0.5334480499965226, 0.4527125227876706, 0.4755822128857967, 0.6160949479980028, 0.5904554083574044, 0.4723597581053188, 0.4639404844544225, 0.5373124956416887, 0.4689378364385882, 0.5795251266326057, 0.4903421225156201, 0.5145180062854806, 0.4053891047445834, 0.4988053102750745, 0.5656089715630832, 0.5069950996703326, 0.4359037497558391, 0.5363412591990445, 0.5898934434493417, 0.485318590107711, 0.38085861557225004, 0.5238780802694044, 0.5259984373471209, 0.4698353420208921, 0.4501890145382339, 0.576639732725097, 0.42605447259979257, 0.4645359364091285, 0.5044726953231192, 0.5241593872483931, 0.5670857570171162, 0.48487774768665554, 0.5967696930706684, 0.4843127018498602, 0.5059059705841146, 0.5662880462047267, 0.48376697700263344, 0.5032683466983233, 0.38877777386752327, 0.43905247249789797, 0.6241695025383313, 0.5015847930766537, 0.5300289820769102, 0.4499673476758215, 0.5455192640344328, 0.5480492997126202, 0.49833962836204754, 0.5871419999060483, 0.5775246733537253, 0.5149942704168754, 0.5420521578569637, 0
0.5745339255544534, 0.5644735465569599, 0.44798457669801034, 0.5796124135034882, 0.5616783368090028, 0.5799267478770832, 0.6081902456760955, 0.48721387555191586, 0.5156835259023473, 0.5484865887902197, 0.58153449842723, 0.5337156967444157, 0.5944563920719206, 0.5458719708347738, 0.5462733263505978, 0.6263470223359623, 0.588736629449946, 0.5810795333620251, 0.5594298719453015, 0.6215147925995884, 0.5638849419725734, 0.5967746331030241, 0.5758270987108466, 0.5613475207303065, 0.5216762714236998, 0.5873057476225794, 0.5900971468975428, 0.5217567358152626, 0.5449197834910725, 0.5575684449112802, 0.5466820886041996, 0.5587062370677398, 0.57702448905365, 0.5738336360735766, 0.5857248303498122, 0.5433541754567096, 0.5900957355008791, 0.5149695811340855, 0.5292176838184274, 0.5494835289661015, 0.582038041994889, 0.5345445147571094, 0.5598603459020483, 0.6025943247700959, 0.5808808979809134, 0.5996417378559642, 0.6098875701927488, 0.5683269149908777, 0.5923929373579091, 0.5749717207443535, 0.6049452183081446, 0.5618612977109793, 0.5899137750069097, 0.5676000842314824, 0.5770431899871015, 0.5683586498189948, 0.5082973501256394, 0.545257053697998, 0.5346163460222435, 0.5470695771595679, 0.5356659393040506, 0.559227304340382, 0.5926759225971788, 0.6034567819560511, 0.5780576749509236, 0.5977742526359948, 0.59902143048381, 0.5854166454609637, 0.5586912258778062, 0.5929429209813881, 0.5774842135079611, 0.5571608791490723, 0.5584809834571312, 0.5436678365349137, 0.5648234642124489, 0.5880595167934732, 0.5754681234225061, 0.5676190240788486, 0.5457314586231412, 0.5527691720254382, 0.5825188283000812, 0.5643814203764697, 0.5998209737559689, 0.5813236045197365, 0.5646659444968284, 0.6034532320087695, 0.5430409602267012, 0.5766480432149385, 0.6134792716182086, 0.509054548989683, 0.6023647489856705, 0.5572670244322145, 0.5846201699390554, 0.534747525207297, 0.605794681896462, 0.6268828674483395, 0.5289865153309777, 0.549696632856873, 0.5620073652843425, 0.5827084753523251, 0.5664542431987113, 0.6045108784906397, 0.5808445160532063, 0.5799016747097681, 0.6215441323732053, 0.6346154796949451, 0.5740090113651696, 0.5708396249043651, 0.5683556223465689, 0.5522825828381993, 0.5964281775779058, 0.5738447882590146, 0.6003240521921381, 0.5561319841019521, 0.5935275779836645, 0.5536508282209142, 0.6127501459075151, 0.6158560952717607, 0.5509598345978665, 0.5764102565008158, 0.5481354349743744, 0.6078422923270577, 0.572440529982571, 0.5457154409604653]
run_values = run_values_1 + run_values_2

smoothed_data_10 = pd.Series(run_values).rolling(window=10, center=True).mean().dropna()
smoothed_data_30 = pd.Series(run_values).rolling(window=30, center=True).mean().dropna()

x_mark = smoothed_data_30.idxmax()
y_mark = smoothed_data_30.max()

plt.plot(smoothed_data_10)
plt.plot(smoothed_data_30)
plt.axvline(x=337, color="gray")
plt.xlabel("Round")
plt.ylabel("IoU")
plt.legend(labels=["Moving Mean 10", "Moving Mean 30"], loc='lower right', framealpha=1.0)
plt.xlim(0)
# Out:
# (0.0, 497.45)
